# %%
pip install riotwatcher
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from riotwatcher import LolWatcher, ApiError
import pandas as pd

# %%
api_key = 'RGAPI-55e3d7ae-6da4-441d-8132-8b4c2f338fab'
watcher = LolWatcher(api_key)
my_region = 'na1'

# %%
# DIAMOND 1
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'DIAMOND', 'I')
# print(me)
d1 = pd.DataFrame(me)
# DIAMOND 2
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'DIAMOND', 'II')
# print(me)

# %%
d2 = pd.DataFrame(me)
# DIAMOND 3
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'DIAMOND', 'III')
# print(me)
d3 = pd.DataFrame(me)
# DIAMOND 4
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'DIAMOND', 'IV')
# print(me)
d4 = pd.DataFrame(me)

# %%
# Plat 1
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'PLATINUM', 'I')
# print(me)
p1 = pd.DataFrame(me)
# Plat 2
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'PLATINUM', 'II')
# print(me)
p2 = pd.DataFrame(me)
# Plat 3
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'PLATINUM', 'III')
# print(me)
p3 = pd.DataFrame(me)
# Plat 4
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'PLATINUM', 'IV')
# print(me)
p4 = pd.DataFrame(me)

# %%
# Gold 1
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'GOLD', 'I')
# print(me)
g1 = pd.DataFrame(me)
# Gold 2
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'GOLD', 'II')
# print(me)
g2 = pd.DataFrame(me)
# Gold 3
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'GOLD', 'III')
# print(me)
g3 = pd.DataFrame(me)
# Gold 4
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'GOLD', 'IV')
# print(me)
g4 = pd.DataFrame(me)

# %%
# Silver 1
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'SILVER', 'I')
# print(me)
s1 = pd.DataFrame(me)
# Silver 2
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'SILVER', 'II')
# print(me)
s2 = pd.DataFrame(me)
# Silver 3
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'SILVER', 'III')
# print(me)
s3 = pd.DataFrame(me)
# Silver 4
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'SILVER', 'IV')
# print(me)
s4 = pd.DataFrame(me)

# %%
# Bronze 1
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'BRONZE', 'I')
# print(me)
b1 = pd.DataFrame(me)
# Bronze 2
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'BRONZE', 'II')
# print(me)
b2 = pd.DataFrame(me)
# Bronze 3
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'BRONZE', 'III')
# print(me)
b3 = pd.DataFrame(me)
# Bronze 4
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'BRONZE', 'IV')
# print(me)
b4 = pd.DataFrame(me)

# %%
# Iron 1
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'IRON', 'I')
# print(me)
i1 = pd.DataFrame(me)
# Iron 2
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'IRON', 'II')
# print(me)
i2 = pd.DataFrame(me)
# Iron 3
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'IRON', 'III')
# print(me)
i3 = pd.DataFrame(me)
# Iron 4
me = watcher.league.entries(my_region, 'RANKED_SOLO_5x5', 'IRON', 'IV')
# print(me)
i4 = pd.DataFrame(me)

# %%
dataset = pd.DataFrame()

#dataset = dataset.append(c1)
#dataset = dataset.append(gm1)
#dataset = dataset.append(m1)
dataset = dataset.append(d1)
dataset = dataset.append(d2)
dataset = dataset.append(d3)
dataset = dataset.append(d4)
dataset = dataset.append(p1)
dataset = dataset.append(p2)
dataset = dataset.append(p3)
dataset = dataset.append(p4)
dataset = dataset.append(g1)
dataset = dataset.append(g2)
dataset = dataset.append(g3)
dataset = dataset.append(g4)
dataset = dataset.append(s1)
dataset = dataset.append(s2)
dataset = dataset.append(s3)
dataset = dataset.append(s4)
dataset = dataset.append(b1)
dataset = dataset.append(b2)
dataset = dataset.append(b3)
dataset = dataset.append(b4)
dataset = dataset.append(i1)
dataset = dataset.append(i2)
dataset = dataset.append(i3)
dataset = dataset.append(i4)

# %%
dataset.drop('queueType', inplace = True, axis=1)
dataset.drop('veteran', inplace = True, axis=1)
dataset.drop('inactive', inplace = True, axis=1)
dataset.drop('freshBlood', inplace = True, axis=1)
dataset.drop('hotStreak', inplace = True, axis=1)
dataset.drop('miniSeries', inplace = True, axis=1)
dataset
# Out:
#                                  leagueId     tier rank  \
# 0    9ee3ac13-f4eb-4de7-9202-4b3d8596a992  DIAMOND    I
# 1    42d59f56-6560-49af-9c99-6ec6fc6bcfcf  DIAMOND    I
# 2    acba59ee-e527-4113-83db-ee62a34fc7f7  DIAMOND    I
# 3    52a48d3a-ac81-4794-8e37-0ce31b1649c1  DIAMOND    I
# 4    9ad768cd-eedd-4310-8923-4f6334c9981c  DIAMOND    I
# ..                                    ...      ...  ...
# 200  7d3edbd9-9699-4b92-88f6-7ea4286bc5c3     IRON   IV
# 201  5cacc5d4-42da-4c56-a19e-20f4ee41c410     IRON   IV
# 202  859fd285-84c0-4a36-ad1e-265e7cdac457     IRON   IV
# 203  6f7cec5c-8ae5-4a38-8847-b2a8aed5e559     IRON   IV
# 204  342cf777-b75a-48e0-a2bf-761017af36c8     IRON   IV
#
#                                            summonerId    summonerName  \
# 0    72JOCvMoYZouKsqPG3GIc7NqH41UfhxVUAX8kPz9nb0vMaKr           ƒIame
# 1    0WdB9_-yvmXL5zmLQVw3oGk7EZT1LMHVP88j9EbAiYaPX4Y9   Fine Young OG
# 2    SIpxuQgKRwjB-zBZCn71bll8C8TMQxILae75t6Hv2wA2l_I7            a1cu
# ...

# %%
me = watcher.champion_mastery.scores_by_summoner(my_region, '72JOCvMoYZouKsqPG3GIc7NqH41UfhxVUAX8kPz9nb0vMaKr')
print(me)
# Out:
# 179

# %%
level = []
for i in range(len(dataset)):
    if i % 100 == 0:
        print(i)
    try:
        me = watcher.summoner.by_name(my_region, dataset.iloc[i, 4])
        summ_lvl = me['summonerLevel']
        level.append(summ_lvl)
    except:
        print(dataset.iloc[i, 4])
        level.append('-1')
# Out:
# 0
# rzswbr
# QEWQEQWQEQ
# 100
# blue ping
# 200
# ShanShanYuHe33
# YYYLLLYYY
# 300
# Gott der Spitze
# 400
# 500
# 600
# toastzandjam
# 700
# 800
# Gluck MacDonalds
# 900
# PhD in Karmology
# Her Wórld
# Urgeo
# 1000
# 1100
# 1200
# 1300
# ıFox
# auto tune 8
# Peeling
# 1400
# 1500
# 1600
# 1700
# EcsOR
# LUL U SUCK QUIT
# DSF Noob Top
# 1800
# Scfeen
# 1900
# 2000
# 462748217983217
# 2100
# 2200
# 2300
# 2400
# BeNiceToMeOrDie
# 2500
# BigQiu
# The US Bin
# 2600
# Chambs97
# Porror0
# 2700
# Loveuxixi
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# ForBoo
# 3500
# KingofKings2127
# 3600
# 3700
# 3800
# Rainyvapor
# chill karen
# 3900
# bálek
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# Náhn
# 4700
# 4800
# 4900

# %%
champ_pts = []
for i in range(len(dataset)):
    if i % 100 == 0:
        print(i)
    try:
        me = watcher.champion_mastery.scores_by_summoner(my_region, dataset.iloc[i, 3])
        champ_pts.append(me)
    except:
        print(dataset.iloc[i, 3])
        champ_pts.append('-1')
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900

# %%
print(champ_pts)
# Out:
# [179, 179, 453, 301, 463, 53, 115, 92, 175, 114, 110, 131, 83, 112, 267, 205, 105, 126, 148, 131, 143, 208, 129, 501, 102, 186, 235, 45, 291, 181, 191, 146, 220, 197, 95, 178, 276, 142, 115, 194, 131, 219, 85, 366, 338, 317, 140, 297, 101, 109, 125, 172, 474, 193, 181, 272, 99, 176, 293, 250, 292, 409, 268, 407, 360, 51, 321, 215, 202, 290, 58, 271, 178, 302, 348, 111, 268, 262, 442, 283, 97, 382, 151, 174, 273, 167, 289, 310, 146, 96, 102, 120, 333, 127, 143, 371, 384, 253, 235, 224, 313, 97, 247, 83, 138, 313, 237, 211, 186, 282, 286, 188, 502, 343, 141, 259, 229, 267, 90, 451, 54, 275, 138, 338, 263, 260, 304, 373, 279, 113, 114, 165, 57, 188, 258, 214, 422, 209, 296, 151, 140, 209, 169, 128, 173, 187, 60, 342, 396, 205, 251, 241, 216, 136, 92, 156, 81, 317, 155, 169, 215, 107, 107, 109, 178, 507, 154, 172, 133, 197, 430, 102, 229, 32, 230, 85, 219, 189, 128, 123, 159, 272, 496, 74, 149, 202, 317, 299, 143, 85, 63, 169, 138, 31, 143, 116, 109, 192, 262, 98, 245, 63, 398, 371, 229,
# ...

# %%
print(level)
# Out:
# [72, 83, 387, 169, 327, 72, 105, 94, '-1', 89, 116, 102, 53, 85, 205, 202, 46, 84, 147, 99, 86, 169, 66, 464, 49, 145, 315, 96, 149, 71, 120, 75, 140, 110, 58, 81, 182, 78, 105, 192, 71, 212, 34, '-1', 211, 209, 88, 238, 53, 74, 86, 73, 285, 108, 90, 273, 52, 94, 127, 189, 167, 263, 116, 335, 182, 40, 363, 94, 104, 449, 62, 241, 111, 167, 247, 85, 185, 145, 196, 291, 86, 264, 99, 111, 202, 76, 174, 218, 102, 48, 69, 145, 362, 60, 377, 313, 234, 129, 164, 116, 149, 81, 141, 50, 147, 212, 142, 119, 146, 214, 202, 124, 367, 345, 85, 149, 119, 245, 58, 357, 44, 136, 84, 308, 199, 164, 139, 265, 352, 74, 105, 134, 93, 111, 117, 368, 299, 171, 122, 181, 157, 119, 92, 127, 97, 114, 60, 183, 349, 124, 159, 143, 249, 171, 77, 146, 42, 238, 104, 86, 161, 117, 79, 69, 235, 294, 214, 141, 69, 130, 360, 72, 149, 73, 269, 56, 169, 117, 82, 51, 137, 159, 346, 64, 86, 106, 166, 203, 142, '-1', 63, 161, 134, 102, 76, 105, 99, 113, 258, 67, 149, 52, 361, 248, 140, 237, 246, 48, 227, 133, 521, 285, 123
# ...

# %%
me = watcher.summoner.by_name(my_region, '7 pg muda')
summ_lvl = me['summonerLevel']
print(summ_lvl)
# Out:
# 210

# %%
dataset['summoner level'] = level
dataset['champion mastery'] = champ_pts
dataset
# Out:
#                                  leagueId     tier rank  \
# 0    9ee3ac13-f4eb-4de7-9202-4b3d8596a992  DIAMOND    I
# 1    42d59f56-6560-49af-9c99-6ec6fc6bcfcf  DIAMOND    I
# 2    acba59ee-e527-4113-83db-ee62a34fc7f7  DIAMOND    I
# 3    52a48d3a-ac81-4794-8e37-0ce31b1649c1  DIAMOND    I
# 4    9ad768cd-eedd-4310-8923-4f6334c9981c  DIAMOND    I
# ..                                    ...      ...  ...
# 200  7d3edbd9-9699-4b92-88f6-7ea4286bc5c3     IRON   IV
# 201  5cacc5d4-42da-4c56-a19e-20f4ee41c410     IRON   IV
# 202  859fd285-84c0-4a36-ad1e-265e7cdac457     IRON   IV
# 203  6f7cec5c-8ae5-4a38-8847-b2a8aed5e559     IRON   IV
# 204  342cf777-b75a-48e0-a2bf-761017af36c8     IRON   IV
#
#                                            summonerId    summonerName  \
# 0    72JOCvMoYZouKsqPG3GIc7NqH41UfhxVUAX8kPz9nb0vMaKr           ƒIame
# 1    0WdB9_-yvmXL5zmLQVw3oGk7EZT1LMHVP88j9EbAiYaPX4Y9   Fine Young OG
# 2    SIpxuQgKRwjB-zBZCn71bll8C8TMQxILae75t6Hv2wA2l_I7            a1cu
# ...

# %%
dataset.to_csv('riotapi.csv', index = False)

# %%
dataset.to_csv('fixedriotapi.csv', index = False)
